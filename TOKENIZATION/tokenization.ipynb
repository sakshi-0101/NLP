# %%
corpus=""" Hello Welcome, I am learning NLP here.
I want to become expert in NLP.
"""

# %%
print(corpus)
# Out:
#  Hello Welcome, I am learning NLP here.
# I want to become expert in NLP.

# %%
##Tokenization
##sentence --->paragraphs
from nltk.tokenize import sent_tokenize

# %%
import nltk
nltk.download('punkt', download_dir='C:/nltk_data')
# Out:
# [nltk_data] Downloading package punkt to C:/nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# True

# %%
import nltk
nltk.data.path.append('C:/nltk_data')

# %%
sent_tokenize(corpus)
# Out:
# [' Hello Welcome, I am learning NLP here.', 'I want to become expert in NLP.']

# %%
import nltk
nltk.download('punkt')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\sakshi\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\sakshi\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt_tab.zip.
# True

# %%
documents=sent_tokenize(corpus)
type(documents)
# Out:
# list

# %%
for sentence in documents:
    print(sentence)
# Out:
#  Hello Welcome, I am learning NLP here.
# I want to become expert in NLP.

# %%
##Tokenization
##Paragraph --> word
##sentence-->words
from nltk.tokenize import word_tokenize

# %%
word_tokenize(corpus)
# Out:
# ['Hello',
#  'Welcome',
#  ',',
#  'I',
#  'am',
#  'learning',
#  'NLP',
#  'here',
#  '.',
#  'I',
#  'want',
#  'to',
#  'become',
#  'expert',
#  'in',
#  'NLP',
#  '.']

# %%
from nltk.tokenize  import wordpunct_tokenize

# %%
wordpunct_tokenize(corpus)
# Out:
# ['Hello',
#  'Welcome',
#  ',',
#  'I',
#  'am',
#  'learning',
#  'NLP',
#  'here',
#  '.',
#  'I',
#  'want',
#  'to',
#  'become',
#  'expert',
#  'in',
#  'NLP',
#  '.']

# %%
from nltk.tokenize import TreebankWordTokenizer

# %%
tokenizer=TreebankWordTokenizer()

# %%
tokenizer.tokenize(corpus)
##difference:fullstop with here is treated as one with here not seprately.
# Out:
# ['Hello',
#  'Welcome',
#  ',',
#  'I',
#  'am',
#  'learning',
#  'NLP',
#  'here.',
#  'I',
#  'want',
#  'to',
#  'become',
#  'expert',
#  'in',
#  'NLP',
#  '.']
